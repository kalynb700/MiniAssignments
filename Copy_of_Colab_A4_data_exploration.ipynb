# %% [markdown]
# <a href="https://colab.research.google.com/github/kalynb700/MiniAssignments/blob/main/Copy_of_Colab_A4_data_exploration.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Explorating the Tree of Life
#
# <table><tr><td>
# <img src="https://i.guim.co.uk/img/static/sys-images/Guardian/Pix/pictures/2008/04/17/DarwinSketch.article.jpg?width=445&quality=85&auto=format&fit=max&s=c7f89552d12b8495b2b4eb4d7a5bc391" width=200><a href="https://i.guim.co.uk/img/static/sys-images/Guardian/Pix/pictures/2008/04/17/DarwinSketch.article.jpg?width=445&quality=85&auto=format&fit=max&s=c7f89552d12b8495b2b4eb4d7a5bc391">source</a></td><td><img src="http://www.greennature.ca/greennature/taxonomy/tree_of_life.png" width=300><a href="http://www.greennature.ca/greennature/taxonomy/tree_of_life.png">source</a></td></tr></table>

# %% [markdown]
# In this hands-on exercise, you answer the following questions by using pandas data structures and methods to analyze the eukaryote genome data store in the following tab-delimited file. https://raw.githubusercontent.com/csbfx/advpy122-data/master/euk.tsv

# %%
import pandas as pd
# %matplotlib inline

# this input file is tab-delimited instead of comma-delimited
tsvFile = "https://raw.githubusercontent.com/csbfx/advpy122-data/master/euk.tsv"
# Load the csv file into a dataframe
euk = pd.read_csv(tsvFile, sep="\t")
euk
# Out:
#                          Species   Kingdom           Class   Size (Mb)  \
# 0     Emiliania huxleyi CCMP1516  Protists  Other Protists  167.676000
# 1           Arabidopsis thaliana    Plants     Land Plants  119.669000
# 2                    Glycine max    Plants     Land Plants  979.046000
# 3            Medicago truncatula    Plants     Land Plants  412.924000
# 4           Solanum lycopersicum    Plants     Land Plants  828.349000
# ...                          ...       ...             ...         ...
# 8297    Saccharomyces cerevisiae     Fungi     Ascomycetes    3.993920
# 8298    Saccharomyces cerevisiae     Fungi     Ascomycetes    0.586761
# 8299    Saccharomyces cerevisiae     Fungi     Ascomycetes   12.020400
# 8300    Saccharomyces cerevisiae     Fungi     Ascomycetes   11.960900
# 8301    Saccharomyces cerevisiae     Fungi     Ascomycetes   11.820700
#
#           GC% Number of genes Number of proteins  Publication year  \
# 0        64.5           38549              38554              2013
# 1     36.0529           38311              48265              2001
# 2     35.1153           59847              71219              2010
# 3      34.047           37603              41939              2011
# 4     35.6991           31200              37660              2010
# ...       ...             ...                ...               ...
# 8297     38.2               -                  -              2017
# 8298  38.5921             155                298              1992
# 8299  38.2971               -                  -              2018
# 8300  38.2413               -                  -              2018
# 8301  38.2536               -                  -              2018
#
#      Assembly status
# 0           Scaffold
# 1         Chromosome
# 2         Chromosome
# 3         Chromosome
# 4         Chromosome
# ...              ...
# 8297        Scaffold
# 8298      Chromosome
# 8299      Chromosome
# 8300      Chromosome
# 8301      Chromosome
#
# [8302 rows x 9 columns]

# %% [markdown]
# ## Q1. How many Mammals have at least 20,000 genes? What are their scientific names?
# *Note:*
# - *Mammals are under Class*
# - *Scientific names are under Species*

# %%
# final answers:
# How many mammals have at least 20,000 genes?   134
# What are their scientific names?   see table below



# coercing the gene number to an int
euk["Number of genes"] =  pd.to_numeric(euk["Number of genes"],  errors='coerce')

# How many mammals have at least 20,000 genes
euk[(euk.Class == 'Mammals') & (euk['Number of genes'] >= 20000)].value_counts()

# Scientific names of mammals that have at least 20,000 genes
euk[(euk.Class == 'Mammals') & (euk['Number of genes'] >= 20000)].Species
# Out:
# 44             Homo sapiens
# 45             Mus musculus
# 65        Rattus norvegicus
# 70              Felis catus
# 74               Bos taurus
#                ...
# 4977      Rattus norvegicus
# 5087         Macaca mulatta
# 5152    Macaca fascicularis
# 5180     Cricetulus griseus
# 6781           Mus musculus
# Name: Species, Length: 134, dtype: object

# %% [markdown]
# ### Q2. Animals are a part of Kingdom. How many records are there for each Class of Animals?

# %%
# How many records are there for each class of animals?   See table below
euk[(euk.Kingdom == 'Animals')].Class.value_counts()
# Out:
# Class
# Mammals          658
# Insects          602
# Fishes           282
# Other Animals    210
# Birds            172
# Roundworms       162
# Flatworms         47
# Reptiles          41
# Amphibians         7
# Name: count, dtype: int64

# %% [markdown]
# ### Q3. Animals are a part of Kingdom. How many unique Species are there for each Class of Animals?

# %%
# Answer: see table below


for clas in euk[euk.Kingdom == 'Animals'].Class.unique():
    print(clas, euk[euk.Class == clas].Species.nunique())
# Out:
# Roundworms 111
# Insects 360
# Fishes 217
# Other Animals 169
# Mammals 296
# Amphibians 6
# Birds 140
# Flatworms 34
# Reptiles 38

# %% [markdown]
# ### Q4. What are the unique scientific names of Mammals with the genus name Macaca?
# *Recall: the scientific name starts with genus followed by a space and then the species name. Example: Homo sapiens, where Homo is the genus name and sapiens is the species name.*

# %%
# separates the species in the mammal category. Gets the first string and finds the unique ones
#euk.Species.str.split()

euk[(euk.Class == 'Mammals')].Species.str.split().str[0].unique()
# Out:
# array(['Homo', 'Mus', 'Rattus', 'Felis', 'Bos', 'Ovis', 'Canis', 'Sus',
#        'Ornithorhynchus', 'Equus', 'Pan', 'Macaca', 'Monodelphis',
#        'Loxodonta', 'Sorex', 'Erinaceus', 'Cavia', 'Notamacropus',
#        'Echinops', 'Dasypus', 'Oryctolagus', 'Pongo', 'Lemur', 'Papio',
#        'Callithrix', 'Otolemur', 'Tupaia', 'Ictidomys', 'Nomascus',
#        'Myotis', 'Pteropus', 'Tursiops', 'Microcebus', 'Dipodomys',
#        'Ochotona', 'Bubalus', 'Galeopterus', 'Vicugna', 'Choloepus',
#        'Gorilla', 'Procavia', 'Ailuropoda', 'Cricetulus', 'Sarcophilus',
#        'Mustela', 'Platanista', 'Odocoileus', 'Saimiri', 'Heterocephalus',
#        'Inia', 'Phoca', 'Glis', 'Hippopotamus', 'Vombatus', 'Eumetopias',
#        'Tamandua', 'Thryonomys', 'Cebus', 'Nycticebus', 'Eschrichtius',
#        'Kogia', 'Monodon', 'Phocoena', 'Megaptera', 'Balaenoptera',
#        'Eubalaena', 'Rangifer', 'Rousettus', 'Rhinopithecus',
#        'Semnopithecus', 'Vulpes', 'Neomonachus', 'Callorhinus',
#        'Ammotragus', 'Nasalis', 'Enhydra', 'Gulo', 'Panthera', 'Sousa',
#        'Bison', 'Diceros', 'Dicerorhinus', 'Moschus', 'Castor',
#        'Chinchilla', 'Leptonychotes', 'Manis', 'Capra', 'Camelus',
#        'Jaculus', 'Pantholops', 'Cervus', 'Ailurus', 'Eulemur',
#        'Microtus', 'Condylura', 'Rhinolophus', 'Peromyscus', 'Tapirus',
#        'Eptesicus', 'Ceratotherium', 'Orycteropus', 'Chrysochloris',
#        'Octodon', 'Elephantulus', 'Daubentonia', 'Mesocricetus',
#        'Artibeus', 'Oryx', 'Puma', 'Lasiurus', 'Nannospalax', 'Myodes',
#        'Physeter', 'Chlorocebus', 'Urocitellus', 'Delphinapterus',
#        'Phodopus', 'Ursus', 'Cercocebus', 'Zalophus', 'Odobenus',
#        'Orcinus', 'Ctenomys', 'Aotus', 'Acinonyx', 'Elaphurus', 'Lipotes',
#        'Hipposideros', 'Desmodus', 'Uropsilus', 'Plecturocebus',
#        'Theropithecus', 'Acomys', 'Neotoma', 'Fukomys', 'Neovison',
#        'Saiga', 'Tympanoctomys', 'Taxidea', 'Okapia', 'Hyaena',
#        'Capreolus', 'Antilocapra', 'Axis', 'Pseudois', 'Pygathrix',
#        'Ziphius', 'Rhizomys', 'Cheirogaleus', 'Erythrocebus', 'Prolemur',
#        'Carollia', 'Anoura', 'Tonatia', 'Phascolarctos', 'Meriones',
#        'Pteronotus', 'Beatragus', 'Propithecus', 'Eidolon', 'Megaderma',
#        'Pontoporia', 'Trichechus', 'Mirza', 'Lepus', 'Indri',
#        'Neophocaena', 'Marmota', 'Mandrillus', 'Colobus', 'Spermophilus',
#        'Apodemus', 'Lynx', 'Lycaon', 'Bradypus', 'Myrmecophaga',
#        'Chaetophractus', 'Tolypeutes', 'Miniopterus', 'Carlito',
#        'Ellobius', 'Lagenorhynchus', 'Psammomys', 'Sigmodon', 'Myocastor',
#        'Octomys', 'Ondatra', 'Piliocolobus', 'Solenodon', 'Giraffa',
#        'Noctilio', 'Eonycteris', 'Mungos', 'Helogale', 'Mirounga',
#        'Cryptoprocta', 'Suricata', 'Spilogale', 'Paradoxurus',
#        'Pteronura', 'Mellivora', 'Xerus', 'Catagonus', 'Zapus', 'Ateles',
#        'Saguinus', 'Scalopus', 'Tragulus', 'Tadarida', 'Mormoops',
#        'Pipistrellus', 'Murina', 'Pithecia', 'Micronycteris', 'Microgale',
#        'Hemitragus', 'Onychomys', 'Heterohyrax', 'Hystrix', 'Petromus',
#        'Muscardinus', 'Mesoplodon', 'Ctenodactylus', 'Dolichotis',
#        'Macroglossus', 'Hydrochoerus', 'Craseonycteris', 'Cricetomys',
#        'Dinomys', 'Graphiurus', 'Cercopithecus', 'Crocidura', 'Alouatta',
#        'Aplodontia', 'Allactaga', 'Capromys', 'Phyllostomus', 'Grammomys',
#        'Dasyprocta', 'Perognathus', 'Cuniculus', 'Arctocephalus'],
#       dtype=object)

# %% [markdown]
# ### Q5. Modify the Species names to only contain the scientific names  and create a new dataframe.
#
# Some of the names in the Species column have more than two parts, such as `Emiliania huxleyi CCMP1516`. Create a new column `Species` that contains only the first two parts of name, such as `Emiliania huxleyi`. Combine this new Species column with `Kingdom`, `Class`, `Size (Mb)`, `Number of genes`, and `Number of proteins` and store this new dataframe as `df_species`.
#
# Hint: Follow Q3 in Lecture 4 with a little twist. Instead of just getting the first element from the split results, you will get the first two elements using `.str[0:2]` which will give you a list. You can then use `.str.join(" ")` to change it back to a string.

# %%
# combine with the other columns

euk['Species']=euk.Species.str.split(" ").str[0:2].str.join(" ")

df_species = euk[["Species", "Kingdom", "Class", "Size (Mb)", "Number of genes", "Number of proteins"]]
df_species
# Out:
#                        Species   Kingdom           Class   Size (Mb)  \
# 0            Emiliania huxleyi  Protists  Other Protists  167.676000
# 1         Arabidopsis thaliana    Plants     Land Plants  119.669000
# 2                  Glycine max    Plants     Land Plants  979.046000
# 3          Medicago truncatula    Plants     Land Plants  412.924000
# 4         Solanum lycopersicum    Plants     Land Plants  828.349000
# ...                        ...       ...             ...         ...
# 8297  Saccharomyces cerevisiae     Fungi     Ascomycetes    3.993920
# 8298  Saccharomyces cerevisiae     Fungi     Ascomycetes    0.586761
# 8299  Saccharomyces cerevisiae     Fungi     Ascomycetes   12.020400
# 8300  Saccharomyces cerevisiae     Fungi     Ascomycetes   11.960900
# 8301  Saccharomyces cerevisiae     Fungi     Ascomycetes   11.820700
#
#       Number of genes Number of proteins
# 0             38549.0              38554
# 1             38311.0              48265
# 2             59847.0              71219
# 3             37603.0              41939
# 4             31200.0              37660
# ...               ...                ...
# 8297              NaN                  -
# 8298            155.0                298
# 8299              NaN                  -
# 8300              NaN                  -
# 8301              NaN                  -
#
# [8302 rows x 6 columns]

# %% [markdown]
# ### Q6. Create a pie plot using pandas to show the number of unique Species in each Class of Animals using the new dataframe you created in Q5
# Hint: First, create a new dataframe that contains the number of unique Species and the index is the corresponding Animals Class. Then, use that dataframe to plot the pie plot.
# [Check out this documentation](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.plot.pie.html)

# %%
# Create a new dataframe that contains the number of unique Species and
# the index is the corresponding Animals Class.

unique = []
for clas in df_species[df_species.Kingdom == 'Animals'].Class.unique():
  unique.append(
      {
          'Animal Class': clas,
          'Number of Unique Species': df_species[df_species.Class == clas].Species.nunique()
      }
  )
df_unique = pd.DataFrame(unique)
df_unique.set_index('Animal Class', inplace=True)
df_unique
# Out:
#                Number of Unique Species
# Animal Class
# Roundworms                          111
# Insects                             360
# Fishes                              217
# Other Animals                       169
# Mammals                             296
# Amphibians                            6
# Birds                               140
# Flatworms                            34
# Reptiles                             38

# %%
# Create a panda pie plot using the dataframe above

df_unique.plot.pie(y = 'Number of Unique Species', figsize=(9, 9))
# Out:
# <Axes: ylabel='Number of Unique Species'>
